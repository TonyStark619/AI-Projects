# %%
import pandas as pd

# We are bypassing the CSV file and creating the data directly in memory
data = {
    'area': [1000, 1500, 2000, 2500, 3000],
    'price': [50, 72, 100, 120, 155]
}

# Convert it into a Pandas DataFrame
df = pd.DataFrame(data)

# Display the table
df
# Out:
#    area  price
# 0  1000     50
# 1  1500     72
# 2  2000    100
# 3  2500    120
# 4  3000    155
